# %% [markdown]
# # EARTHLAB 2026 — Setup Verification
#
# Run all cells in this notebook to check that your Python environment is ready for the workshop.
# If everything passes, you will see **Setup complete** at the bottom.

# %%
import sys
print(f"Python {sys.version}")
assert sys.version_info >= (3, 10), "Python 3.10 or later is required"
print("OK")

# %% [markdown]
# ## Core libraries

# %%
import numpy as np
print(f"numpy {np.__version__}")

import pandas as pd
print(f"pandas {pd.__version__}")

import scipy
print(f"scipy {scipy.__version__}")

import matplotlib
print(f"matplotlib {matplotlib.__version__}")

import seaborn as sns
print(f"seaborn {sns.__version__}")

print("OK")

# %% [markdown]
# ## Machine learning (PyTorch)

# %%
import torch
print(f"torch {torch.__version__}")

import torchvision
print(f"torchvision {torchvision.__version__}")

import sklearn
print(f"scikit-learn {sklearn.__version__}")

print("OK")

# %% [markdown]
# ## Bayesian statistics

# %%
import pymc as pm
print(f"pymc {pm.__version__}")

import arviz as az
print(f"arviz {az.__version__}")

print("OK")

# %% [markdown]
# ## Climate and earth science data

# %%
import xarray as xr
print(f"xarray {xr.__version__}")

import netCDF4
print(f"netCDF4 {netCDF4.__version__}")

from PIL import Image
print(f"pillow {Image.__version__}")

print("OK")

# %% [markdown]
# ## Quick sanity check

# %%
# Quick test: create a small tensor and run a simple operation
x = torch.randn(3, 3)
y = torch.randn(3, 3)
z = torch.matmul(x, y)
print(f"PyTorch tensor multiplication: {z.shape} — OK")

# Quick test: fit a tiny scikit-learn model
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit([[1],[2],[3]], [2,4,6])
print(f"scikit-learn linear regression: coef={model.coef_[0]:.1f} — OK")

print()

# %% [markdown]
# ---
#
# ## Setup complete
#
# If all cells ran without errors, your environment is ready for EARTHLAB 2026.
#
# Please let Francesco or Alice know on Slack that your setup is working.
